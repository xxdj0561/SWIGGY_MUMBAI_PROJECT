# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import numpy as np # linear algebra
import pandas as pd

# %%
df1 = pd.read_csv("../input/swiggy-mumbai/Swiggy_CBD-belapur-restaurants.csv")

# %%
from itertools import repeat
given_value ='belapur-restaurants'
new_list_1=[]
new_list_1.extend(repeat(given_value,93))

# %%
new_list_1

# %%
  
df1.insert(loc = 0,
          column = 'RESTAURANTS NAME',
          value = new_list_1)
# show the dataframe
df1

# %%
df1

# %%
df1.shape

# %%
print(df1)

# %%
df1

# %%
df1["title"]

# %%
df1["title"].value_counts().describe

# %%
df1["title"].value_counts().plot( kind = 'bar',figsize= (30,5))

# %%
df1["ratt"]

# %%
df1["ratt"].value_counts().plot( kind = 'bar',figsize= (30,5))

# %%
df1["ratt"]

# %%
column_split = df1['ratt'].str.split('•', expand=True)

# %%
column_split

# %%
column_split[1]

# %%
column_split[2]

# %%
column_split.drop(1, axis = 1, inplace = True)

# %%
column_split

# %%
column_split_1 = column_split.rename(columns={column_split.columns[0]: 'RATING',column_split.columns[1]: 'DISCOUNT'})

# %%
column_split_1

# %%
df_filtered = column_split_1[column_split_1['RATING'] != "--"]

# %%
df_filtered

# %%
type(column_split_1["RATING"])

# %%
df_filtered["RATING"].describe()

# %%
print("AVG RATING",df_filtered["RATING"].mean)

# %%
df_filtered["RATING"].value_counts()

# %%
column_split_1 = df_filtered

# %%
column_split_1["RATING"].value_counts()

# %%
import pandas as pd
my_tab = pd.crosstab(index=column_split_1["RATING"],  # Make a crosstab
                     columns="Total Number of order")                  # Name the count column

my_tab

# %%
prob_od_order = my_tab/my_tab.sum()
prob_od_order

# %%
column_split_1["RATING"].value_counts().plot( kind = 'bar',figsize= (30,5))

# %%
column_split_1["RATING"].value_counts().plot( kind = 'density',figsize= (30,5))

# %%
column_split_1["RATING"].value_counts().plot( kind = 'pie',figsize= (30,5))

# %%
my_tab.value_counts().plot( kind = 'bar',figsize= (30,5))

# %%
my_tab.value_counts().plot( kind = 'pie',figsize= (30,5))

# %%
my_tab.boxplot(column="Total Number of order",
                     by= "RATING",
                     figsize = (8,8));

# %%
my_tab.hist(column="Total Number of order",        # Column to plot
              figsize=(8,8),         # Plot size
              color="blue",          # Plot color
              bins=20,               # Use 50 bins
              range= (0,15));

# %%
df1

# %%
ff = df1['spec'].str.split(',', expand=True)

# %%
ff

# %%
ff[[0]].append(ff[[1]], ignore_index=True)

# %%
cols = [ff[col].squeeze() for col in ff]
cc = pd.concat(cols, ignore_index=True)
cc

# %%
 pd.Categorical(cc)

# %%
pd.Categorical(cc).describe()

# %%
cc.describe()

# %%
cc.value_counts()

# %%
my_tab = pd.Categorical(cc).describe()

# %%
my_tab

# %%
my_tab.value_counts()

# %%
sum_ = sum_.rename(index={0: 'Indian'})

# %%
 my_tab.drop(["NaN"],inplace=True)

# %%
 my_tab = my_tab.append(sum_)

# %%
my_tab = my_tab.iloc[0:65]

# %%
my_tab

# %%
my_tab.value_counts()

# %%
sum_

# %%
my_tab

# %%
my_tab.drop(["freqs"], axis = 1, inplace = True)

# %%
my_tab.counts

# %%
my_tab.value_counts

# %%
 pd.Categorical(cc).unique

# %%
my_tab.counts.plot( kind = 'pie',figsize= (30,5),startangle = 90, shadow = True)
plt.legend(title = "Order Type")

# %%
my_tab.plot( kind = 'bar',figsize= (30,5))

# %%
df2 = pd.read_csv("../input/swiggy-mumbai/Swiggy_Kharghar-restaurants.csv")

# %%
df2

# %%
df2["title"].value_counts().plot( kind = 'bar',figsize= (30,5))

# %%
df2['ratt']

# %%
column_split = df2['ratt'].str.split('•', expand=True)

# %%
column_split

# %%
column_split.drop(1, axis = 1, inplace = True)

# %%
column_split

# %%
column_split_1 = column_split.rename(columns={column_split.columns[0]: 'RATING',column_split.columns[1]: 'DISCOUNT'})

# %%
column_split_1

# %%
df_filtered_1 = column_split_1[column_split_1['RATING'] != "--"]

# %%
df_filtered_1

# %%
print("AVG RATING",df_filtered_1["RATING"].mean)

# %%
my_tab["Total Number of order"].describe()
